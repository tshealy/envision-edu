# %%
import numpy as np

# %%
nums = list(np.arange(1,301))

# %%
nums_dict = {}

# %%
count = [1, 2, 3]*100

# %%
for a in count:
    nums_dict[nums[0]] = a
    my_count = 0
    nums.pop(my_count)
    my_count + 1

# %%
nums_dict
# Out:
# {1: 1,
#  2: 2,
#  3: 3,
#  4: 1,
#  5: 2,
#  6: 3,
#  7: 1,
#  8: 2,
#  9: 3,
#  10: 1,
#  11: 2,
#  12: 3,
#  13: 1,
#  14: 2,
#  15: 3,
#  16: 1,
#  17: 2,
#  18: 3,
#  19: 1,
#  20: 2,
#  21: 3,
#  22: 1,
#  23: 2,
#  24: 3,
#  25: 1,
#  26: 2,
#  27: 3,
#  28: 1,
#  29: 2,
#  30: 3,
#  31: 1,
#  32: 2,
#  33: 3,
#  34: 1,
#  35: 2,
#  36: 3,
#  37: 1,
#  38: 2,
#  39: 3,
#  40: 1,
#  41: 2,
#  42: 3,
#  43: 1,
#  44: 2,
#  45: 3,
#  46: 1,
#  47: 2,
#  48: 3,
#  49: 1,
#  50: 2,
#  51: 3,
#  52: 1,
#  53: 2,
#  54: 3,
#  55: 1,
#  56: 2,
#  57: 3,
#  58: 1,
#  59: 2,
#  60: 3,
#  61: 1,
#  62: 2,
#  63: 3,
#  64: 1,
#  65: 2,
#  66: 3,
#  67: 1,
#  68: 2,
#  69: 3,
#  70: 1,
#  71: 2,
#  72: 3,
#  73: 1,
#  74: 2,
#  75: 3,
#  76: 1,
#  77: 2,
#  78: 3,
#  79: 1,
#  80: 2,
#  81: 3,
#  82: 1,
#  83: 2,
#  84: 3,
#  85: 1,
#  86: 2,
#  87: 3,
#  88: 1,
#  89: 2,
#  90: 3,
#  91: 1,
#  92: 2,
#  93: 3,
#  94: 1,
#  95: 2,
#  96: 3,
#  97: 1,
#  98: 2,
#  99: 3,
#  100: 1,
# ...

# %%
data1 = [ k for k, v in nums_dict.items() if v == 1 ]
data2 = [ k for k, v in nums_dict.items() if v == 2 ]
data3 = [ k for k, v in nums_dict.items() if v == 3 ]

# %%
print(data1)
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70, 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136, 139, 142, 145, 148, 151, 154, 157, 160, 163, 166, 169, 172, 175, 178, 181, 184, 187, 190, 193, 196, 199, 202, 205, 208, 211, 214, 217, 220, 223, 226, 229, 232, 235, 238, 241, 244, 247, 250, 253, 256, 259, 262, 265, 268, 271, 274, 277, 280, 283, 286, 289, 292, 295, 298]

# %%
print(data2)
# Out:
# [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146, 149, 152, 155, 158, 161, 164, 167, 170, 173, 176, 179, 182, 185, 188, 191, 194, 197, 200, 203, 206, 209, 212, 215, 218, 221, 224, 227, 230, 233, 236, 239, 242, 245, 248, 251, 254, 257, 260, 263, 266, 269, 272, 275, 278, 281, 284, 287, 290, 293, 296, 299]

# %%
print(data3)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300]

# %%
def check_value(val):
    if val in data0:
        print("data0")
    elif val in data1:
        print("data1")
    elif val in data2:
        print("data2")
    else: print("not listed")

# %%
check_value(2)
# Out:
# data2
